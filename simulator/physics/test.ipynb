# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# membrane

WT = 20000
dt = 0.01
dx = 0.1
D = 5*dt/(dx*dx)

dens = np.zeros(100)

# Fic's law : d(dens(t,x)) / dt = d^2(dens(t,x)) / (dx)^2

# %%
import matplotlib.pyplot as plt

i = 0
retFile = open("./result.txt", "w")
data = [ i for i in range(30,1,-1) ]
while(i<30):
    x = data[i]
    plt.plot(i,x,'o')
    i+=1
    retFile.write('i:{}, data:{}\n'.format(str(i),str(data[i])))
    plt.pause(0.1)
plt.show()
retFile.close()

print("finish")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-5-43c3d67e77a5> in <module>
#       8     plt.plot(i,x,'o')
#       9     i+=1
# ---> 10     retFile.write('i:{}, data:{}\n'.format(str(i),str(data[i])))
#      11     plt.pause(0.1)
#      12 plt.show()
#
# IndexError: list index out of range
